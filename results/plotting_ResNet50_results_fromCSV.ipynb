# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Results/current_results/ResNet50_results.csv', delimiter = ';')

# %%
df.head()
# Out:
#    epoch       acc        f1      loss   val_acc    val_f1  val_loss
# 0      0  0.646408  0.563734  0.763194  0.406349  0.571824  2.798315
# 1      1  0.697348  0.621398  0.641000  0.593651  0.000000  6.573161
# 2      2  0.711927  0.637776  0.597542  0.593651  0.000000  4.676145
# 3      3  0.716055  0.634962  0.592065  0.593651  0.000000  0.902802
# 4      4  0.707799  0.626689  0.591170  0.593651  0.000000  0.790206

# %%
train_acc = df['acc']
train_f1 = df['f1']
train_loss = df['loss']
val_acc = df['val_acc']
val_f1 = df['val_f1']
val_loss = df['val_loss']

# %%
# plot train and validation Accuracy vs 100 Epochs
plt.figure(1)
line1 = plt.plot(range(1,101),train_acc,'r',label='train_acc')
line2 = plt.plot(range(1,101), val_acc, 'b', label='val_acc')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
# plt.legend(handles=[line1,line2])
plt.title('ResNet50_train validation accuracy vs 100 epoch')
plt.savefig('plot_ResNet50_train_valid_accuracy_100epoch')
plt.show()

# %%
# plot train and validation f1 score vs 100 Epochs
plt.figure(2)
line1 = plt.plot(range(1,101),train_f1,'r',label='train_f1')
line2 = plt.plot(range(1,101), val_f1, 'b', label='val_f1')
plt.ylabel('F1 Score')
plt.xlabel('Epoch')
# plt.legend(handles=[line1,line2])
plt.title('ResNet50 train validation f1 score vs 100 epoch')
plt.savefig('plot_ResNet50_train_valid_f1_100epoch')
plt.show()

# %%
# plot train and validation Loss vs 100 Epochs
plt.figure(3)
line1 = plt.plot(range(1,101),train_loss,'r',label='train_loss')
line2 = plt.plot(range(1,101), val_loss, 'b', label='val_loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
# plt.legend(handles=[line1,line2])
plt.title('ResNet50 train validation loss vs 100 epoch')
plt.savefig('plot_ResNet50_train_valid_loss_100epoch')
plt.show()
