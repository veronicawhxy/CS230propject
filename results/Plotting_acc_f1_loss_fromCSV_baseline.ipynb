# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
#with open("../Results/current_results/results_baseline_adam_lr0001_epoch100.csv", 'r') as csvfile:

df = pd.read_csv('../Results/current_results/results_baseline_adam_lr0001_epoch100.csv', delimiter = ';')

# %%
df.head()
# Out:
#    epoch       acc        f1      loss   val_acc    val_f1  val_loss
# 0      0  0.565783  0.516930  0.770114  0.598413  0.509602  0.676848
# 1      0  0.575531  0.476397  0.777522  0.600000  0.545024  0.696955
# 2      1  0.597400  0.465256  0.722065  0.614286  0.506052  0.653521
# 3      2  0.617074  0.489102  0.692212  0.631746  0.488359  0.632762
# 4      3  0.629545  0.484047  0.675606  0.636508  0.586067  0.666674

# %%
train_acc = df['acc']
train_f1 = df['f1']
train_loss = df['loss']
val_acc = df['val_acc']
val_f1 = df['val_f1']
val_loss = df['val_loss']

# %%
# plot train and validation Accuracy vs 100 Epochs
plt.figure(1)
line1 = plt.plot(range(1,102),train_acc,'r',label='train_acc')
line2 = plt.plot(range(1,102), val_acc, 'b', label='val_acc')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
# plt.legend(handles=[line1,line2])
plt.title('Baseline model train validation accuracy vs 100 epoch using Adam lr0001')
plt.savefig('plot_baseline_adam0001_train_valid_accuracy_100epoch')
plt.show()

# %%
# plot train and validation f1 score vs 100 Epochs
plt.figure(2)
line1 = plt.plot(range(1,102),train_f1,'r',label='train_f1')
line2 = plt.plot(range(1,102), val_f1, 'b', label='val_f1')
plt.ylabel('F1 Score')
plt.xlabel('Epoch')
# plt.legend(handles=[line1,line2])
plt.title('Baseline model train validation f1 score vs 100 epoch using Adam lr0001')
plt.savefig('plot_baseline_adam0001_train_valid_f1_100epoch')
plt.show()

# %%
# plot train and validation Loss vs 100 Epochs
plt.figure(3)
line1 = plt.plot(range(1,102),train_loss,'r',label='train_loss')
line2 = plt.plot(range(1,102), val_loss, 'b', label='val_loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
# plt.legend(handles=[line1,line2])
plt.title('Baseline model train validation loss vs 100 epoch using Adam lr0001')
plt.savefig('plot_baseline_adam0001_train_valid_loss_100epoch')
plt.show()
